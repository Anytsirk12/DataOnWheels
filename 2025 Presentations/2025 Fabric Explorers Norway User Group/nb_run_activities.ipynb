# %% [markdown]
# ## Pull in UDFs

# %%
# %run nb_udfs
# Out:
# StatementMeta(, cbb2d96e-ec4b-4bcb-874b-11f403f663f9, 307, Finished, Available, Finished)

# %% [markdown]
# ## Run Activities

# %%
workspace = 'Fabric of Middle-Earth' #have to escape the & symbol using %26% 
lakehouse = 'lh_the_hoard'
act_table = 'factActivities'
date_offset = 1
#defaults the activity data to grab yesterday's data. The API only goes back 28 days maximum.
# Out:
# StatementMeta(, cbb2d96e-ec4b-4bcb-874b-11f403f663f9, 308, Finished, Available, Finished)

# %%
"""
Gets the Power BI activity events for a specific day (offset from today).
:param date_offset: Number of days ago (0 = today, 1 = yesterday). Defaults to 1.
"""
# Calculate the UTC date string
target_date = (dt.utcnow() - timedelta(days=date_offset)).strftime('%Y-%m-%d')
start_date = f"{target_date}T00:00:00.00Z"
end_date = f"{target_date}T23:59:59.99Z"
print(f"🔍 Fetching activity for {start_date} to {end_date} - date offset {date_offset}")
# Out:
# StatementMeta(, cbb2d96e-ec4b-4bcb-874b-11f403f663f9, 309, Finished, Available, Finished)
# 🔍 Fetching activity for 2025-05-31T00:00:00.00Z to 2025-05-31T23:59:59.99Z - date offset 1

# %%
# Call the API

windows = generate_hourly_windows(target_date)
#print(windows)

#test = list_activity_events('2025-04-19T00:00:00.000Z','2025-04-19T00:59:59.999Z')
#print(test)

# Define dimension load config
activity_path = udf_GetFilePath(workspace, lakehouse, act_table)
natural_key = ['Id']
primary_key = 'tableId'


for start_time, end_time in windows:
    print(f"Fetching events from {start_time} to {end_time}")
    df_activities = list_activity_events(start_time, end_time)
    try:
        df_activities = spark.createDataFrame(df_activities)
        #df_activities.show(1)  # Show a sample if needed
        # Upsert to Delta
        return_val = udf_UpsertDimension(
            df_activities, 
            dimensionType=1,
            targetPath=activity_path,
            naturalKeyColumnList=natural_key,
            primaryKeyColumnName=primary_key,
            flagSoftDeletes=False
        )
        print(return_val)

    except ValueError as e:
        print(f"No activities found for the time window {start_time} to {end_time}. Skipping...")
# Out:
# StatementMeta(, cbb2d96e-ec4b-4bcb-874b-11f403f663f9, 310, Finished, Available, Finished)
# Fetching events from 2025-05-31T00:00:00.000Z to 2025-05-31T00:59:59.999Z
# No activities found for the time window 2025-05-31T00:00:00.000Z to 2025-05-31T00:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T01:00:00.000Z to 2025-05-31T01:59:59.999Z
# No activities found for the time window 2025-05-31T01:00:00.000Z to 2025-05-31T01:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T02:00:00.000Z to 2025-05-31T02:59:59.999Z
# No activities found for the time window 2025-05-31T02:00:00.000Z to 2025-05-31T02:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T03:00:00.000Z to 2025-05-31T03:59:59.999Z
# No activities found for the time window 2025-05-31T03:00:00.000Z to 2025-05-31T03:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T04:00:00.000Z to 2025-05-31T04:59:59.999Z
# No activities found for the time window 2025-05-31T04:00:00.000Z to 2025-05-31T04:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T05:00:00.000Z to 2025-05-31T05:59:59.999Z
# No activities found for the time window 2025-05-31T05:00:00.000Z to 2025-05-31T05:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T06:00:00.000Z to 2025-05-31T06:59:59.999Z
# No activities found for the time window 2025-05-31T06:00:00.000Z to 2025-05-31T06:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T07:00:00.000Z to 2025-05-31T07:59:59.999Z
# No activities found for the time window 2025-05-31T07:00:00.000Z to 2025-05-31T07:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T08:00:00.000Z to 2025-05-31T08:59:59.999Z
# No activities found for the time window 2025-05-31T08:00:00.000Z to 2025-05-31T08:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T09:00:00.000Z to 2025-05-31T09:59:59.999Z
# No activities found for the time window 2025-05-31T09:00:00.000Z to 2025-05-31T09:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T10:00:00.000Z to 2025-05-31T10:59:59.999Z
# No activities found for the time window 2025-05-31T10:00:00.000Z to 2025-05-31T10:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T11:00:00.000Z to 2025-05-31T11:59:59.999Z
# No activities found for the time window 2025-05-31T11:00:00.000Z to 2025-05-31T11:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T12:00:00.000Z to 2025-05-31T12:59:59.999Z
# No activities found for the time window 2025-05-31T12:00:00.000Z to 2025-05-31T12:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T13:00:00.000Z to 2025-05-31T13:59:59.999Z
# No activities found for the time window 2025-05-31T13:00:00.000Z to 2025-05-31T13:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T14:00:00.000Z to 2025-05-31T14:59:59.999Z
# No activities found for the time window 2025-05-31T14:00:00.000Z to 2025-05-31T14:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T15:00:00.000Z to 2025-05-31T15:59:59.999Z
# No activities found for the time window 2025-05-31T15:00:00.000Z to 2025-05-31T15:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T16:00:00.000Z to 2025-05-31T16:59:59.999Z
# No activities found for the time window 2025-05-31T16:00:00.000Z to 2025-05-31T16:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T17:00:00.000Z to 2025-05-31T17:59:59.999Z
# No activities found for the time window 2025-05-31T17:00:00.000Z to 2025-05-31T17:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T18:00:00.000Z to 2025-05-31T18:59:59.999Z
# No activities found for the time window 2025-05-31T18:00:00.000Z to 2025-05-31T18:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T19:00:00.000Z to 2025-05-31T19:59:59.999Z
# No activities found for the time window 2025-05-31T19:00:00.000Z to 2025-05-31T19:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T20:00:00.000Z to 2025-05-31T20:59:59.999Z
# No activities found for the time window 2025-05-31T20:00:00.000Z to 2025-05-31T20:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T21:00:00.000Z to 2025-05-31T21:59:59.999Z
# No activities found for the time window 2025-05-31T21:00:00.000Z to 2025-05-31T21:59:59.999Z. Skipping...
# Fetching events from 2025-05-31T22:00:00.000Z to 2025-05-31T22:59:59.999Z
# ✅ Upsert complete
# {'startTime': '2025-06-01 01:10:49.929312', 'stopTime': '2025-06-01 01:10:55.303940', 'details': '0 records updated, 3 records inserted from 3 staging rows to abfss://253a31af-7442-450f-b93a-680a4831c265@onelake.dfs.fabric.microsoft.com/7ea68a16-ce87-4757-aaaf-48a22e04038c/Tables/factActivities'}
# Fetching events from 2025-05-31T23:00:00.000Z to 2025-05-31T23:59:59.999Z
# ✅ Upsert complete
# {'startTime': '2025-06-01 01:10:55.924872', 'stopTime': '2025-06-01 01:11:01.706666', 'details': '0 records updated, 1952 records inserted from 1952 staging rows to abfss://253a31af-7442-450f-b93a-680a4831c265@onelake.dfs.fabric.microsoft.com/7ea68a16-ce87-4757-aaaf-48a22e04038c/Tables/factActivities'}
